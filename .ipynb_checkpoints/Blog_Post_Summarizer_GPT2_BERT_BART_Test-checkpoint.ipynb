# %% [markdown]
# # 1. Installing Transformers and Importing Dependencies

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\depik\miniconda\lib\site-packages (4.34.0)
# Requirement already satisfied: filelock in c:\users\depik\miniconda\lib\site-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\depik\miniconda\lib\site-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\depik\miniconda\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\depik\miniconda\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\depik\miniconda\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\depik\miniconda\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\depik\miniconda\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in c:\users\depik\miniconda\lib\site-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\depik\miniconda\lib\site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\depik\miniconda\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: fsspec in c:\users\depik\miniconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.9.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\depik\miniconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.6.3)
# Requirement already satisfied: colorama in c:\users\depik\miniconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\depik\miniconda\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\depik\miniconda\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\depik\miniconda\lib\site-packages (from requests->transformers) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\depik\miniconda\lib\site-packages (from requests->transformers) (2022.12.7)

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in c:\users\depik\miniconda\lib\site-packages (0.1.99)

# %%
# !pip install bert-extractive-summarizer
# Out:
# Requirement already satisfied: bert-extractive-summarizer in c:\users\depik\miniconda\lib\site-packages (0.10.1)
# Requirement already satisfied: transformers in c:\users\depik\miniconda\lib\site-packages (from bert-extractive-summarizer) (4.34.0)
# Requirement already satisfied: scikit-learn in c:\users\depik\miniconda\lib\site-packages (from bert-extractive-summarizer) (1.3.1)
# Requirement already satisfied: spacy in c:\users\depik\miniconda\lib\site-packages (from bert-extractive-summarizer) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\depik\miniconda\lib\site-packages (from scikit-learn->bert-extractive-summarizer) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\depik\miniconda\lib\site-packages (from scikit-learn->bert-extractive-summarizer) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\depik\miniconda\lib\site-packages (from scikit-learn->bert-extractive-summarizer) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\depik\miniconda\lib\site-packages (from scikit-learn->bert-extractive-summarizer) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (0.3.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\depik\miniconda\lib\site-packages (from spacy->bert-extractive-summarizer) (3.3.0)
# Requirement already satisfied: filelock in c:\users\depik\miniconda\lib\site-packages (from transformers->bert-extractive-summarizer) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\depik\miniconda\lib\site-packages (from transformers->bert-extractive-summarizer) (0.17.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\depik\miniconda\lib\site-packages (from transformers->bert-extractive-summarizer) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\depik\miniconda\lib\site-packages (from transformers->bert-extractive-summarizer) (2023.10.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in c:\users\depik\miniconda\lib\site-packages (from transformers->bert-extractive-summarizer) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\depik\miniconda\lib\site-packages (from transformers->bert-extractive-summarizer) (0.4.0)
# Requirement already satisfied: fsspec in c:\users\depik\miniconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers->bert-extractive-summarizer) (2023.9.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\depik\miniconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers->bert-extractive-summarizer) (4.6.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\depik\miniconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->bert-extractive-summarizer) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\depik\miniconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->bert-extractive-summarizer) (2.10.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\depik\miniconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\depik\miniconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\depik\miniconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\depik\miniconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\depik\miniconda\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy->bert-extractive-summarizer) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\depik\miniconda\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy->bert-extractive-summarizer) (0.1.3)
# Requirement already satisfied: colorama in c:\users\depik\miniconda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy->bert-extractive-summarizer) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\depik\miniconda\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy->bert-extractive-summarizer) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.16.0,>=0.7.0 in c:\users\depik\miniconda\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy->bert-extractive-summarizer) (0.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\depik\miniconda\lib\site-packages (from jinja2->spacy->bert-extractive-summarizer) (2.1.3)

# %%
from transformers import pipeline
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # 2. Loading Summarization Pipeline

# %%
from summarizer import Summarizer, TransformerSummarizer
from transformers import pipeline

# %% [markdown]
# ## GPT-2

# %%
GPT2_model = TransformerSummarizer(transformer_type="GPT2",transformer_model_key="gpt2-medium")

def gptSum(body):
  return ''.join(GPT2_model(body, min_length=60))

# %% [markdown]
# ## BERT

# %%
bert_model = Summarizer()

def bertSum(body):
  return ''.join(bert_model(body, min_length=60))

# %% [markdown]
# ## BART

# %%
bart_model = pipeline('summarization', model='facebook/bart-large-cnn', tokenizer='facebook/bart-large-cnn')

def bartSum(body):
   summary=bart_model(body, min_length = round(0.1 * len(body.split(' '))), max_length = round(0.2 * len(body.split(' '))), do_sample=False, truncation=True)
   return summary[0]['summary_text']

# %% [markdown]
# # 3. Get Blog Post

# %%
URL = "https://medium.com/@kevinnokiawriting/why-reading-is-part-of-success-6c9cea0c1edb"

# %%
r = requests.get(URL)

# %%
r.text
# Out:
# '<!doctype html><html lang="en"><head><title data-rh="true">Why Reading Is Part of Success. I have read for almost 4 years. Even… | by Kevin Nokia | Medium</title><meta data-rh="true" charset="utf-8"/><meta data-rh="true" name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1"/><meta data-rh="true" name="theme-color" content="#000000"/><meta data-rh="true" name="twitter:app:name:iphone" content="Medium"/><meta data-rh="true" name="twitter:app:id:iphone" content="828256236"/><meta data-rh="true" property="al:ios:app_name" content="Medium"/><meta data-rh="true" property="al:ios:app_store_id" content="828256236"/><meta data-rh="true" property="al:android:package" content="com.medium.reader"/><meta data-rh="true" property="fb:app_id" content="542599432471018"/><meta data-rh="true" property="og:site_name" content="Medium"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="article:published_time" content="2023-06-07T04:33:41.171Z"/><meta data-rh="true" name="title" content="Why Reading Is Part of Success. I have read for almost 4 years. Even… | by Kevin Nokia | Medium"/><meta data-rh="true" property="og:title" content="Why Reading Is Part of Success"/><meta data-rh="true" property="al:android:url" content="medium://p/6c9cea0c1edb"/><meta data-rh="true" property="al:ios:url" content="medium://p/6c9cea0c1edb"/><meta data-rh="true" property="al:android:app_name" content="Medium"/><meta data-rh="true" name="description" content="I have read for almost 4 years. Even though my reading skills are still decent, I found it interesting that it separates readers and non-readers. What I’m going to tell you about is my opinion. This…"/><meta data-rh="true" property="og:description" content="I have read for almost 4 years. Even though my reading skills are still decent, I found it interesting that it separates readers and…"/><meta data-rh="true" property="og:url" content="https://medium.com/@kevinnokiawriting/why-reading-is-part-of-success-6c9cea0c1edb"/><meta data-rh="true" property="al:web:url" content="https://medium.com/@kevinnokiawriting/why-reading-is-part-of-success-6c9cea0c1edb"/><meta data-rh="true" property="og:image" content="https://miro.medium.com/v2/resize:fit:1200/1*R9LHpr-N4S1hLyPK_W_gyQ.jpeg"/><meta data-rh="true" property="article:author" content="https://medium.com/@kevinnokiawriting"/><meta data-rh="true" name="author" content="Kevin Nokia"/><meta data-rh="true" name="robots" content="index,follow,max-image-preview:large"/><meta data-rh="true" name="referrer" content="unsafe-url"/><meta data-rh="true" property="twitter:title" content="Why Reading Is Part of Success"/><meta data-rh="true" name="twitter:site" content="@Medium"/><meta data-rh="true" name="twitter:app:url:iphone" content="medium://p/6c9cea0c1edb"/><meta data-rh="true" property="twitter:description" content="I have read for almost 4 years. Even though my reading skills are still decent, I found it interesting that it separates readers and…"/><meta data-rh="true" name="twitter:image:src" content="https://miro.medium.com/v2/resize:fit:1200/1*R9LHpr-N4S1hLyPK_W_gyQ.jpeg"/><meta data-rh="true" name="twitter:card" content="summary_large_image"/><meta data-rh="true" name="twitter:label1" content="Reading time"/><meta data-rh="true" name="twitter:data1" content="4 min read"/><meta data-rh="true" name="twitter:tile:template:testing" content="2"/><meta data-rh="true" name="twitter:tile:image" content="https://miro.medium.com/v2/resize:fit:1200/1*R9LHpr-N4S1hLyPK_W_gyQ.jpeg"/><meta data-rh="true" name="twitter:tile:info1:icon" content="Person"/><meta data-rh="true" name="twitter:tile:info1:text" content="Kevin Nokia"/><meta data-rh="true" name="twitter:tile:info2:icon" content="Calendar"/><meta data-rh="true" name="twitter:tile:info2:text" content="Jun 7, 2023"/><meta data-rh="true" name="twitter:cta" content="Read on Medium"/><link data-rh="true" rel="icon" href="https://miro.medium.com/v2/1*m-R_Bk ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
results = soup.find_all(['h1', 'p'])

# %%
results
# Out:
# [<h1 class="pw-post-title et eu ev be ew ex ey ez fa fb fc fd fe ff fg fh fi fj fk fl fm fn fo fp fq fr fs ft fu fv bj" data-testid="storyTitle" id="4dd7">Why Reading Is Part of Success</h1>,
#  <p class="be b gr gs bj"><a class="af ag ah ai aj ak al am an ao ap aq ar gt" data-testid="authorName" href="/@kevinnokiawriting?source=post_page-----6c9cea0c1edb--------------------------------" rel="noopener follow">Kevin Nokia</a></p>,
#  <p class="be b gr gs gw"><span><a class="gx gy ah ai aj ak al am an ao ap aq ar gz ha hb" href="/m/signin?actionUrl=https%3A%2F%2Fmedium.com%2F_%2Fsubscribe%2Fuser%2F5ea8423844cb&amp;operation=register&amp;redirect=https%3A%2F%2Fmedium.com%2F%40kevinnokiawriting%2Fwhy-reading-is-part-of-success-6c9cea0c1edb&amp;user=Kevin+Nokia&amp;userId=5ea8423844cb&amp;source=post_page-5ea8423844cb----6c9cea0c1edb---------------------post_header-----------" rel="noopener follow">Follow</a></span></p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">73</span></p>,
#  <p class="be b bf z gw">Listen</p>,
#  <p class="be b bf z gw">Share</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="26e8">I have read for almost 4 years. Even though my reading skills are still decent, I found it interesting that it separates readers and non-readers. What I’m going to tell you about is my opinion. This is not a generalization because I know there’s someone out there who doesn’t need reading for their part of success.</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="06cc">I always feel enjoyment after reading a couple of books. I love reading as much as I love writing. Reading is like my input, and my output is through my writing. The articles that I wrote are not perfect. I know that I need to learn and improve more through reading and, of course, evaluation.</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="5031">My journey started with reading. I will never get this far without reading. I haven’t succeeded yet, but I know that my reading skills will be part of my success in the future. It’s not because of how the knowledge is implemented in my brain from reading, even though it’s one of the parts of success. It’s <em class="mg">imbecility.</em></p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll ni ln lo lp nj lr ls lt nk lv lw lx nl lz ma mb nm md me mf eo bj" id="9e37">What do I mean by "imbecile"? From <a class="af lh" href="https://www.google.com/url?sa=t&amp;rct=j&amp;q=&amp;esrc=s&amp;cd=&amp;cad=rja&amp;uact=8&amp;ved=2ahUKEwju_efkkOf-AhVURWwGHXONDgcQFnoECBkQAw&amp;url=https%3A%2F%2Fwww.merriam-webster.com%2Fdictionary%2Fimbecile%23%3A%7E%3Atext%3D%253A%2520a%2520foolish%2520or%2520stupid%2520person&amp;usg=AOvVaw1IDI52ADnFFJOjz1-3NKbI" rel="noopener ugc nofollow" target="_blank">Merriam-Webster.com</a>, imbecile is a foolish or stupid person. I didn’t say that most people are imbeciles or foolish, but what I want to point out is their stubbornness and vanity. People who have those two inside of them are blocking their way to learning something valuable. Which leads them to imbecile.</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="f02a">There’s always someone who thinks that they are the best at what they do. They used to say, “You don’t have to tell me what to do, because I know what I have to do.” Well, there’s nothing wrong with that, but if you close your ears for the entire time and don’t let yourself learn, it will result in disaster. There’s always something you can learn from other people. Even if you can’t see it, there’s no one above or below you. As Sadhguru said,</p>,
#  <p class="li lj mg lk b ll lm ln lo lp lq lr ls nr lu lv lw ns ly lz ma nt mc md me mf eo bj" id="f366"><strong class="lk ew">“Don’t look up to anyone; don’t look down on anyone.”</strong></p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="079d">Well, the same as I am. You don’t need to look up or down on someone like me or anybody else on the internet or in the world. We might learn something, but we don’t have to overestimate or underestimate other people. Respect is the key to learning, and that’s why we need to listen to other people.</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="63b3">Let’s go back to the part about success. Knowing what you need to fix, you can become an expert in what you pursue. If you find it hard to listen to other people, start by reading. That’s why reading is part of success. Reading is pretty much a simple tool to teach you how to listen. There are thousands of words that you can choose to listen to or ignore. Even so, making yourself sit and read is actually part of humility.</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="b6e5">You want to understand what the writer has to say. You want to learn from and maybe implement what the writer says. That’s why reading is my part of success because, I used to be stubborn and vanity. I thought I had all the skills in the world. I thought I was better than anybody else, and I don’t need someone to tell me what to do. Well, as a result, I became imbecile. I end up embarrassing myself in front of other people.</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="56e3">You can start by reading for 5 minutes every day. If it’s still too hard for you, you can start reading for only 1 minute. I used to read for 1 minute every day. It’s actually pretty funny when I used to read for 1 minute every day because</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="bb9a">I would sit down,</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="73d5">start the timer, open up pages of the book, and end up wasting 40 seconds of it.</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="23d1">Read it for like 10 seconds, and then close the book for 10 seconds.</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="0a1e">You can do that too, because the main part is that you have to go through the process of putting yourself to start. This is what I called progress. If someone can do it, you can do it too. Humble yourself to read, which will lead you to other parts of success. You just accomplished one simple step toward success!</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="f891">I am Kevin Nokia, and I hope that from this article we can learn together and improve together. I hope you guys can give me criticism and suggestions to improve my writing. Follow me, and I will follow you back to build the community of writers. ❤</p>,
#  <p class="pw-post-body-paragraph li lj ev lk b ll lm ln lo lp lq lr ls lt lu lv lw lx ly lz ma mb mc md me mf eo bj" id="6447">Check out my new Blogspot: <a class="af lh" href="https://kevinnokia.blogspot.com/" rel="noopener ugc nofollow" target="_blank">kevinnokia.blogspot.com</a></p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b bf z gw"><span class="pw-responses-count jn jo">73</span></p>,
#  <p class="be b bf z bj"><span class="eo">Consistently Write For People!</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Kevin Nokia</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">90</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Kevin Nokia</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">24</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Kevin Nokia</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">30</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Kevin Nokia</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">6</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Nick Wignall</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">194</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Mary Mpembee</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">74</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Hugh McGuire</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">347</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Henry Tinker</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">173</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Deandra Zaneta</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">75</span></p>,
#  <p class="be b jm z uj uk ul um un uo up uq bj">Titta Tiara</p>,
#  <p class="be b jm z gw"><span class="iw">--</span></p>,
#  <p class="be b jm z gw"><span class="pw-responses-count jn jo">37</span></p>,
#  <p class="be b jm z gw">Help</p>,
#  <p class="be b jm z gw">Status</p>,
#  <p class="be b jm z gw">Writers</p>,
#  <p class="be b jm z gw">Blog</p>,
#  <p class="be b jm z gw">Careers</p>,
#  <p class="be b jm z gw">Privacy</p>,
#  <p class="be b jm z gw">Terms</p>,
#  <p class="be b jm z gw">About</p>,
#  <p class="be b jm z gw">Text to speech</p>,
#  <p class="be b jm z gw">Teams</p>]

# %%
text = [result.text for result in results]
ARTICLE = ' '.join(text)

# %%
ARTICLE
# Out:
# 'Why Reading Is Part of Success Kevin Nokia Follow -- 73 Listen Share I have read for almost 4 years. Even though my reading skills are still decent, I found it interesting that it separates readers and non-readers. What I’m going to tell you about is my opinion. This is not a generalization because I know there’s someone out there who doesn’t need reading for their part of success. I always feel enjoyment after reading a couple of books. I love reading as much as I love writing. Reading is like my input, and my output is through my writing. The articles that I wrote are not perfect. I know that I need to learn and improve more through reading and, of course, evaluation. My journey started with reading. I will never get this far without reading. I haven’t succeeded yet, but I know that my reading skills will be part of my success in the future. It’s not because of how the knowledge is implemented in my brain from reading, even though it’s one of the parts of success. It’s imbecility. What do I mean by "imbecile"? From Merriam-Webster.com, imbecile is a foolish or stupid person. I didn’t say that most people are imbeciles or foolish, but what I want to point out is their stubbornness and vanity. People who have those two inside of them are blocking their way to learning something valuable. Which leads them to imbecile. There’s always someone who thinks that they are the best at what they do. They used to say, “You don’t have to tell me what to do, because I know what I have to do.” Well, there’s nothing wrong with that, but if you close your ears for the entire time and don’t let yourself learn, it will result in disaster. There’s always something you can learn from other people. Even if you can’t see it, there’s no one above or below you. As Sadhguru said, “Don’t look up to anyone; don’t look down on anyone.” Well, the same as I am. You don’t need to look up or down on someone like me or anybody else on the internet or in the world. We might learn something, but we don’t have to overestimate or underestimate other people. Respect is the key to learning, and that’s why we need to listen to other people. Let’s go back to the part about success. Knowing what you need to fix, you can become an expert in what you pursue. If you find it hard to listen to other people, start by reading. That’s why reading is part of success. Reading is pretty much a simple tool to teach you how to listen. There are thousands of words that you can choose to listen to or ignore. Even so, making yourself sit and read is actually part of humility. You want to understand what the writer has to say. You want to learn from and maybe implement what the writer says. That’s why reading is my part of success because, I used to be stubborn and vanity. I thought I had all the skills in the world. I thought I was better than anybody else, and I don’t need someone to tell me what to do. Well, as a result, I became imbecile. I end up embarrassing myself in front of other people. You can start by reading for 5 minutes every day. If it’s still too hard for you, you can start reading for only 1 minute. I used to read for 1 minute every day. It’s actually pretty funny when I used to read for 1 minute every day because I would sit down, start the timer, open up pages of the book, and end up wasting 40 seconds of it. Read it for like 10 seconds, and then close the book for 10 seconds. You can do that too, because the main part is that you have to go through the process of putting yourself to start. This is what I called progress. If someone can do it, you can do it too. Humble yourself to read, which will lead you to other parts of success. You just accomplished one simple step toward success! I am Kevin Nokia, and I hope that from this article we can learn together and improve together. I hope you guys can give me criticism and suggestions to improve my writing. Follow me, and I will follow you back to build the community of writers. ❤ Check out my new Blogspot: kevinnok ...

# %% [markdown]
# # 4. Data Preprocessing

# %% [markdown]
# ## Chunk Article

# %%
ARTICLE = ARTICLE.replace('.', '.<eos>')
ARTICLE = ARTICLE.replace('!', '!<eos>')
ARTICLE = ARTICLE.replace('?', '?<eos>')
sentences = ARTICLE.split('<eos>')

# %%
sentences
# Out:
# ['Why Reading Is Part of Success Kevin Nokia Follow -- 73 Listen Share I have read for almost 4 years.',
#  ' Even though my reading skills are still decent, I found it interesting that it separates readers and non-readers.',
#  ' What I’m going to tell you about is my opinion.',
#  ' This is not a generalization because I know there’s someone out there who doesn’t need reading for their part of success.',
#  ' I always feel enjoyment after reading a couple of books.',
#  ' I love reading as much as I love writing.',
#  ' Reading is like my input, and my output is through my writing.',
#  ' The articles that I wrote are not perfect.',
#  ' I know that I need to learn and improve more through reading and, of course, evaluation.',
#  ' My journey started with reading.',
#  ' I will never get this far without reading.',
#  ' I haven’t succeeded yet, but I know that my reading skills will be part of my success in the future.',
#  ' It’s not because of how the knowledge is implemented in my brain from reading, even though it’s one of the parts of success.',
#  ' It’s imbecility.',
#  ' What do I mean by "imbecile"?',
#  ' From Merriam-Webster.',
#  'com, imbecile is a foolish or stupid person.',
#  ' I didn’t say that most people are imbeciles or foolish, but what I want to point out is their stubbornness and vanity.',
#  ' People who have those two inside of them are blocking their way to learning something valuable.',
#  ' Which leads them to imbecile.',
#  ' There’s always someone who thinks that they are the best at what they do.',
#  ' They used to say, “You don’t have to tell me what to do, because I know what I have to do.',
#  '” Well, there’s nothing wrong with that, but if you close your ears for the entire time and don’t let yourself learn, it will result in disaster.',
#  ' There’s always something you can learn from other people.',
#  ' Even if you can’t see it, there’s no one above or below you.',
#  ' As Sadhguru said, “Don’t look up to anyone; don’t look down on anyone.',
#  '” Well, the same as I am.',
#  ' You don’t need to look up or down on someone like me or anybody else on the internet or in the world.',
#  ' We might learn something, but we don’t have to overestimate or underestimate other people.',
#  ' Respect is the key to learning, and that’s why we need to listen to other people.',
#  ' Let’s go back to the part about success.',
#  ' Knowing what you need to fix, you can become an expert in what you pursue.',
#  ' If you find it hard to listen to other people, start by reading.',
#  ' That’s why reading is part of success.',
#  ' Reading is pretty much a simple tool to teach you how to listen.',
#  ' There are thousands of words that you can choose to listen to or ignore.',
#  ' Even so, making yourself sit and read is actually part of humility.',
#  ' You want to understand what the writer has to say.',
#  ' You want to learn from and maybe implement what the writer says.',
#  ' That’s why reading is my part of success because, I used to be stubborn and vanity.',
#  ' I thought I had all the skills in the world.',
#  ' I thought I was better than anybody else, and I don’t need someone to tell me what to do.',
#  ' Well, as a result, I became imbecile.',
#  ' I end up embarrassing myself in front of other people.',
#  ' You can start by reading for 5 minutes every day.',
#  ' If it’s still too hard for you, you can start reading for only 1 minute.',
#  ' I used to read for 1 minute every day.',
#  ' It’s actually pretty funny when I used to read for 1 minute every day because I would sit down, start the timer, open up pages of the book, and end up wasting 40 seconds of it.',
#  ' Read it for like 10 seconds, and then close the book for 10 seconds.',
#  ' You can do that too, because the main part is that you have to go through the process of putting yourself to start.',
#  ' This is what I called progress.',
#  ' If someone can do it, you can do it too.',
#  ' Humble yourself to read, which will lead you to other parts of success.',
#  ' You just accomplished one simple step toward success!',
#  ' I am Kevin Nokia, and I hope that from this article we can learn together and improve together.',
#  ' I hope you guys can give me criticism and suggestions to improve my writing.',
#  ' Follow me, and I will follow you back to build the community of writers.',
#  ' ❤ Check out my new Blogspot: kevinnokia.',
#  'blogspot.',
#  'com -- -- 73 Consistently Write For People!',
#  ' Kevin Nokia -- 90 Kevin Nokia -- 24 Kevin Nokia -- 30 Kevin Nokia -- 6 Nick Wignall -- 194 Mary Mpembee -- 74 Hugh McGuire -- 347 Henry Tinker -- 173 Deandra Zaneta -- 75 Titta Tiara -- 37 Help Status Writers Blog Careers Privacy Terms About Text to speech Teams']

# %%
max_chunk = 500
current_chunk = 0 
chunks = []
for sentence in sentences:
    if len(chunks) == current_chunk + 1: 
        if len(chunks[current_chunk]) + len(sentence.split(' ')) <= max_chunk:
            chunks[current_chunk].extend(sentence.split(' '))
        else:
            current_chunk += 1
            chunks.append(sentence.split(' '))
    else:
        print(current_chunk)
        chunks.append(sentence.split(' '))

for chunk_id in range(len(chunks)):
    chunks[chunk_id] = ' '.join(chunks[chunk_id])
# Out:
# 0

# %%
len(chunks)
# Out:
# 2

# %%
chunks
# Out:
# ['Why Reading Is Part of Success Kevin Nokia Follow -- 73 Listen Share I have read for almost 4 years.  Even though my reading skills are still decent, I found it interesting that it separates readers and non-readers.  What I’m going to tell you about is my opinion.  This is not a generalization because I know there’s someone out there who doesn’t need reading for their part of success.  I always feel enjoyment after reading a couple of books.  I love reading as much as I love writing.  Reading is like my input, and my output is through my writing.  The articles that I wrote are not perfect.  I know that I need to learn and improve more through reading and, of course, evaluation.  My journey started with reading.  I will never get this far without reading.  I haven’t succeeded yet, but I know that my reading skills will be part of my success in the future.  It’s not because of how the knowledge is implemented in my brain from reading, even though it’s one of the parts of success.  It’s imbecility.  What do I mean by "imbecile"?  From Merriam-Webster. com, imbecile is a foolish or stupid person.  I didn’t say that most people are imbeciles or foolish, but what I want to point out is their stubbornness and vanity.  People who have those two inside of them are blocking their way to learning something valuable.  Which leads them to imbecile.  There’s always someone who thinks that they are the best at what they do.  They used to say, “You don’t have to tell me what to do, because I know what I have to do. ” Well, there’s nothing wrong with that, but if you close your ears for the entire time and don’t let yourself learn, it will result in disaster.  There’s always something you can learn from other people.  Even if you can’t see it, there’s no one above or below you.  As Sadhguru said, “Don’t look up to anyone; don’t look down on anyone. ” Well, the same as I am.  You don’t need to look up or down on someone like me or anybody else on the internet or in the world.  We might learn something, but we don’t have to overestimate or underestimate other people.  Respect is the key to learning, and that’s why we need to listen to other people.  Let’s go back to the part about success.  Knowing what you need to fix, you can become an expert in what you pursue.  If you find it hard to listen to other people, start by reading.  That’s why reading is part of success.  Reading is pretty much a simple tool to teach you how to listen.  There are thousands of words that you can choose to listen to or ignore.',
#  ' Even so, making yourself sit and read is actually part of humility.  You want to understand what the writer has to say.  You want to learn from and maybe implement what the writer says.  That’s why reading is my part of success because, I used to be stubborn and vanity.  I thought I had all the skills in the world.  I thought I was better than anybody else, and I don’t need someone to tell me what to do.  Well, as a result, I became imbecile.  I end up embarrassing myself in front of other people.  You can start by reading for 5 minutes every day.  If it’s still too hard for you, you can start reading for only 1 minute.  I used to read for 1 minute every day.  It’s actually pretty funny when I used to read for 1 minute every day because I would sit down, start the timer, open up pages of the book, and end up wasting 40 seconds of it.  Read it for like 10 seconds, and then close the book for 10 seconds.  You can do that too, because the main part is that you have to go through the process of putting yourself to start.  This is what I called progress.  If someone can do it, you can do it too.  Humble yourself to read, which will lead you to other parts of success.  You just accomplished one simple step toward success!  I am Kevin Nokia, and I hope that from this article we can learn together and improve together.  I hope you guys can give me criticism and suggestions to improve my writing.  Follow me, and I will follow you back to build the community of writers.  ❤ Check out my new Blogspot: kevinnokia. blogspot. com -- -- 73 Consistently Write For People!  Kevin Nokia -- 90 Kevin Nokia -- 24 Kevin Nokia -- 30 Kevin Nokia -- 6 Nick Wignall -- 194 Mary Mpembee -- 74 Hugh McGuire -- 347 Henry Tinker -- 173 Deandra Zaneta -- 75 Titta Tiara -- 37 Help Status Writers Blog Careers Privacy Terms About Text to speech Teams']

# %% [markdown]
# # 5. Generating Summaries

# %%
gptResult = []
bertResult = []
bartResult = []

# %%
i = 1
for article in chunks:
  gptResult.append(gptSum(article))
  bertResult.append(bertSum(article))
  bartResult.append(bartSum(article))
  i = i + 1
# Out:
# C:\Users\depik\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\depik\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\depik\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\depik\miniconda\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Assuming gptResult, bertResult, and bartResult have different lengths
max_length = max(len(gptResult), len(bertResult), len(bartResult))

# Pad shorter lists with a placeholder value (e.g., an empty string)
gptResult += [''] * (max_length - len(gptResult))
bertResult += [''] * (max_length - len(bertResult))
bartResult += [''] * (max_length - len(bartResult))

# %%
# Create a DataFrame to store the data
data = {'gpt-summary':gptResult,'bert-summary':bertResult,'bart-summary':bartResult}
df = pd.DataFrame(data)
# Save the data to a CSV file
df.to_csv("article.csv", index=False)
print("Data saved to 'article.csv'")
# Out:
# Data saved to 'article.csv'

# %%
df.head(10)
# Out:
#                                          gpt-summary  \
# 0  Why Reading Is Part of Success Kevin Nokia Fol...
# 1  Why Reading Is Part of Success Kevin Nokia Fol...
# 2  Why Reading Is Part of Success Kevin Nokia Fol...
# 3  Why Reading Is Part of Success Kevin Nokia Fol...
# 4  Why Reading Is Part of Success Kevin Nokia Fol...
# 5  Even so, making yourself sit and read is actua...
# 6  Why Reading Is Part of Success Kevin Nokia Fol...
# 7  Even so, making yourself sit and read is actua...
#
#                                         bert-summary  \
# 0  Why Reading Is Part of Success Kevin Nokia Fol...
# 1  Why Reading Is Part of Success Kevin Nokia Fol...
# 2  Why Reading Is Part of Success Kevin Nokia Fol...
# 3  Why Reading Is Part of Success Kevin Nokia Fol...
# 4  Why Reading Is Part of Success Kevin Nokia Fol...
# 5  Even so, making yourself sit and read is actua...
# 6  Why Reading Is Part of Success Kevin Nokia Fol...
# 7  Even so, making yourself sit and read is actua...
#
#                                         bart-summary
# 0  Why Reading Is Part of Success Kevin Nokia Fol...
# 1  Even so, making yourself sit and read is actua...
# 2  Kevin Nokia: Reading is like my input, and my ...
# 3  Kevin Nokia says reading is part of success be...
# 4
# 5
# 6
# 7

# %% [markdown]
# # 6. Rouge and Blue Score Calculation

# %%
# !pip install rouge-score
# Out:
# Requirement already satisfied: rouge-score in c:\users\depik\miniconda\lib\site-packages (0.1.2)
# Requirement already satisfied: absl-py in c:\users\depik\miniconda\lib\site-packages (from rouge-score) (2.0.0)
# Requirement already satisfied: nltk in c:\users\depik\miniconda\lib\site-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in c:\users\depik\miniconda\lib\site-packages (from rouge-score) (1.24.3)
# Requirement already satisfied: six>=1.14.0 in c:\users\depik\miniconda\lib\site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in c:\users\depik\miniconda\lib\site-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in c:\users\depik\miniconda\lib\site-packages (from nltk->rouge-score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\depik\miniconda\lib\site-packages (from nltk->rouge-score) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\depik\miniconda\lib\site-packages (from nltk->rouge-score) (4.64.1)
# Requirement already satisfied: colorama in c:\users\depik\miniconda\lib\site-packages (from click->nltk->rouge-score) (0.4.6)

# %%
gptRouge = []
bertRouge = []
bartRouge = []

# %%
from rouge_score import rouge_scorer

scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)

# %%
for i in range(0,len(chunks)):
  gptRouge.append(scorer.score(chunks[i], gptResult[i]))
  bertRouge.append(scorer.score(chunks[i], bertResult[i]))
  bartRouge.append(scorer.score(chunks[i], bartResult[i]))

# %%
print('GPT Rouge Scores: ', gptRouge)
print('BERT Rouge Scores: ', bertRouge)
print('BART Rouge Scores: ', bartRouge)
# Out:
# GPT Rouge Scores:  [{'rouge1': Score(precision=1.0, recall=0.15778688524590165, fmeasure=0.27256637168141595), 'rougeL': Score(precision=1.0, recall=0.15778688524590165, fmeasure=0.27256637168141595)}, {'rouge1': Score(precision=0.7402597402597403, recall=0.16521739130434782, fmeasure=0.2701421800947867), 'rougeL': Score(precision=0.38961038961038963, recall=0.08695652173913043, fmeasure=0.14218009478672985)}]
# BERT Rouge Scores:  [{'rouge1': Score(precision=1.0, recall=0.1557377049180328, fmeasure=0.2695035460992908), 'rougeL': Score(precision=1.0, recall=0.1557377049180328, fmeasure=0.2695035460992908)}, {'rouge1': Score(precision=0.618421052631579, recall=0.13623188405797101, fmeasure=0.22327790973871733), 'rougeL': Score(precision=0.34210526315789475, recall=0.07536231884057971, fmeasure=0.12351543942992875)}]
# BART Rouge Scores:  [{'rouge1': Score(precision=1.0, recall=0.1557377049180328, fmeasure=0.2695035460992908), 'rougeL': Score(precision=1.0, recall=0.1557377049180328, fmeasure=0.2695035460992908)}, {'rouge1': Score(precision=1.0, recall=0.14202898550724638, fmeasure=0.2487309644670051), 'rougeL': Score(precision=1.0, recall=0.14202898550724638, fmeasure=0.2487309644670051)}]

# %%
gptFmeasure = []
bertFmeasure = []
bartFmeasure = []

# %%
for i in range(0,len(chunks)):
  gptFmeasure.append(gptRouge[i]['rougeL'].fmeasure)
  bertFmeasure.append(bertRouge[i]['rougeL'].fmeasure)
  bartFmeasure.append(bartRouge[i]['rougeL'].fmeasure)

# %%
from statistics import mean

print("Cumulative F Measure")
print("GPT-2 : ", round(mean(gptFmeasure), 6))
print("BERT : ", round(mean(bertFmeasure), 6))
print("BART : ", round(mean(bartFmeasure), 6))
# Out:
# Cumulative F Measure
# GPT-2 :  0.207373
# BERT :  0.196509
# BART :  0.259117

# %% [markdown]
# ### Here, on evaluation, we can see that BART outperforms all other models (GPT-2 and BERT). Thus, we will be leveraging BART in our web application to summarize more such articles.

# %% [markdown]
# # 7. Output to Text File

# %%
# output_file_path = "bart_summary.txt"
# with open(output_file_path, "w", encoding="utf-8") as file:
#     for summary in bartResult:
#         file.write(summary + "\n")
# print(f"BART summary saved to {output_file_path}")
# Out:
# BART summary saved to bart_summary.txt
